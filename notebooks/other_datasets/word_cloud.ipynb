# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df_women = pd.read_csv("data/adhdwomen-final.csv")
df = pd.read_csv("data/adhd-final.csv")

# %%
# get body column of the df in a single string
#text = " ".join(str(x) for x in df["body"])
text_women = " ".join(str(x) for x in df_women["body"])
# create a word cloud
#wordcloud = WordCloud(width=800, height=400, max_words=200).generate(text)
wordcloud_women = WordCloud(width=1920, height=1080, max_words=500).generate(text_women)

# %%
plt.figure()
plt.imshow(wordcloud_women, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# save the word cloud to a file

# %%
# plt.figure()
# plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()
